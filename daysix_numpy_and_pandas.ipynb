# %%
#RGB -RED,GREEN,BLUE min=0 max=255 
#discoloring image using  numpy
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
imag = Image.open(r"C:\Users\Dell\mountain.jpg")
img= np.array(imag)
img[:,:,0]=np.clip(img[:,:,0]+155,100,1555)
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
#getting quadrants
from PIL import Image
import matplotlib.pyplot as plt
im=Image.open(r"C:\Users\Dell\Downloads\me.jpeg")
image =np.array(im)

plt.imshow(image)

# %%
from PIL import Image
import matplotlib.pyplot as plt
im=Image.open(r"C:\Users\Dell\Downloads\me.jpeg")
image=np.array(im)
image[0:600,0:350,0]=0
image[0:600,350:,1]=0
image[600:,0:350,2]=0
image[600:,350:,0]=250
plt.imshow(image)

# %%
#learning dataframe in pandas

# %%
import pandas as pd
df=pd.DataFrame({"sub":["hindi","english","maths","science"],"marks":[25,26,27,100]})
df
# Out:
#        sub  marks
# 0    hindi     25
# 1  english     26
# 2    maths     27
# 3  science    100

# %%
df.duplicated() #by default it compares through index
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
import pandas as pd
ds=pd.DataFrame({"hello":["h","e","l","l","o"],"whyie":["w","h","y","i","e"]})
ds
# Out:
#   hello whyie
# 0     h     w
# 1     e     h
# 2     l     y
# 3     l     i
# 4     o     e
